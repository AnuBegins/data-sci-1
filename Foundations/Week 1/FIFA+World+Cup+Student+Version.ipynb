# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:2.3em;color:#fff;">------------------
#
# <span style="font-family: Arial; font-weight:bold;font-size:2.3em;color:#fff;">------------------
# <span style="font-family: Arial; font-weight:bold;font-size:2.3em;color:#fa9200;">FIFA World Cup

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:2em;color:#0ab6fa">Dataset Information:-

# %% [markdown]
# The FIFA World Cup is a global football competition contested by the various football-playing nations of the world. It is contested every four years and is the most prestigious and important trophy in the sport of football.
#
# The FIFA World Cup, often simply called the World Cup, is an international association football competition contested by the senior men's national teams of the members of the Fédération Internationale de Football Association (FIFA), the sport's global governing body. The championship has been awarded every four years since the inaugural tournament in 1930, except in 1942 and 1946 when it was not held because of the Second World War.

# %% [markdown]
# The World Cups dataset shows all information about all the World Cups in history till 2014, while the World Cup Matches dataset shows all the results from the matches contested as part of the cups.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:2em;color:#0ab6fa">Problem Statement:-
#
#
#
# A new football club named ‘Brussels United FC’ has just been inaugurated. As a member of this club, you have been assigned a task to carry analysis on matches, players, and world cup data. Here we need to analyze the countries which have won the world cup the most with attendance, goal, and matches per cup based on cities. Also distribution of home and away goals. Whether playing in the home country is a factor for winning or not?
#
# **Steps needs to be followed-**
#
#
# * Total goals scored by year
# * Total matches played and qualified teams by year
# * Matches with the highest number of attendance
# * Cities that hosted highest world cup matches
# * Average attendance by city
# * Teams with the most world cup final victories
# * World cup final results by nation
# * Match outcomes by home and away teams

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:2em;color:#0ab6fa">Data Definition:-
#
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab6fa">1. World Cup Matches Dataset
#
# **Year**: The year in which the match was played
#
# **Datetime**: The Date on which the match was played along with a 24 hour format time
#
# **Stage**: The stage at which the match was played
#
# **Stadium**: Stadium name where the match was held
#
# **City**: The city name, where the match was played
#
# **Home Team Name**: Home team country name
#
# **Home Team Goals**: Total goals scored by the home team by the end of the match
#
# **Away Team Goals**: Total goals scored by the away team by the end of the match
#
# **Away Team Name**: Away team country name
#
# **Win conditions**: Special win condition (if any)
#
# **Attendance**: Total crowd present at the stadium
#
# **Half-time Home Goals**: Goals scored by the home team until half time
#
# **Half-time Away Goals**: Goals scored by the away team until half time
#
# **Referee**: Name of the first referee
#
# **Assistant 1**: Name of the first assistant referee (linesman)
#
# **Assistant 2**: Name of the second assistant referee (linesman)
#
# **RoundID**: Unique ID of the Round
#
# **MatchID**: Unique ID of the Match
#
# **Home Team Initials**: Home team country's three letter initials
#
# **Away Team Initials**: Away team country's three left
#
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab6fa">2. World Cup Players Dataset
#
#
# **RoundID**: Unique ID of the Round
#
# **MatchID**: Unique ID of the Match
#
# **Team Initials**: Player's team country's three letter initials
#
# **Coach Name**: Player's coach name
#
# **Line-up**: Indicates whether the player was in the starting line-up or not
#
# **Shirt Number**: Player's shirt number
#
# **Player Name**: Player's name
#
# **Position**: Position that the player played in
#
# **Event**: Important event involving the player (if any)
#
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab6fa">3. World Cup Dataset
#
# **Year**: Year in which the world cup was held
#
# **Country**: Country where the world cup was held
#
# **Winner**: Team that won the world cup
#
# **Runners-Up**: Team that came second
#
# **Third**: Team that came third
#
# **Fourth**: Team that came fourth
#
# **GoalsScored**: Total goals scored in the world cup
#
# **QualifiedTeams**: Number of teams that qualified for the world cup
#
# **MatchesPlayed**: Total matches played in the world cup
#
# **Attendance**: Total attendance in the world cup

# %%
#Your Code here
import warnings
warnings.filterwarnings('ignore')

import numpy as np                  # Scientific Computing
import pandas as pd                 # Data Analysis
import matplotlib.pyplot as plt     # Plotting
import seaborn as sns               # Statistical Data Visualization

matches  = pd.read_csv("WorldCupMatches.csv")
players  = pd.read_csv("WorldCupPlayers.csv")
cups     = pd.read_csv("WorldCups.csv")

# %%
matches.head()
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# 1                    18346.0                   2.0                   0.0
# 2                    24059.0                   2.0                   0.0
# 3                     2549.0                   1.0                   0.0
# 4                    23409.0                   0.0                   0.0
#
#                   Referee               Assistant 1  \
# 0  LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)
# 1       MACIAS Jose (ARG)  MATEUCCI Francisco (URU)
# 2     TEJADA Anibal (URU)   VALLARINO Ricardo (URU)
# 3   WARNKEN Alberto (CHI)       LANGENUS Jean (BEL)
# 4     REGO Gilberto (BRA)      SAUCEDO Ulises (BOL)
#
#                   Assistant 2  RoundID  MatchID Home Team Initials  \
# 0         REGO Gilberto (BRA)    201.0   1096.0                FRA
# 1       WARNKEN Alberto (CHI)    201.0   1090.0                USA
# 2         BALWAY Thomas (FRA)    201.0   1093.0                YUG
# 3    MATEUCCI Francisco (URU)    201.0   1098.0                ROU
# 4  RADULESCU Constantin (ROU)    201.0   1085.0                ARG
#
#   Away Team Initials
# 0                MEX
# 1                BEL
# 2                BRA
# 3                PER
# 4                FRA

# %%
matches.shape
# Out:
# (4572, 20)

# %%
players.head()
# Out:
#    RoundID  MatchID Team Initials           Coach Name Line-up  Shirt Number  \
# 0      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
# 1      201     1096           MEX     LUQUE Juan (MEX)       S             0
# 2      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
# 3      201     1096           MEX     LUQUE Juan (MEX)       S             0
# 4      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
#
#         Player Name Position Event
# 0       Alex THEPOT       GK   NaN
# 1   Oscar BONFIGLIO       GK   NaN
# 2  Marcel LANGILLER      NaN  G40'
# 3      Juan CARRENO      NaN  G70'
# 4   Ernest LIBERATI      NaN   NaN

# %%
players.shape
# Out:
# (37784, 9)

# %%
cups.head()
# Out:
#    Year      Country      Winner      Runners-Up    Third      Fourth  \
# 0  1930      Uruguay     Uruguay       Argentina      USA  Yugoslavia
# 1  1934        Italy       Italy  Czechoslovakia  Germany     Austria
# 2  1938       France       Italy         Hungary   Brazil      Sweden
# 3  1950       Brazil     Uruguay          Brazil   Sweden       Spain
# 4  1954  Switzerland  Germany FR         Hungary  Austria     Uruguay
#
#    GoalsScored  QualifiedTeams  MatchesPlayed Attendance
# 0           70              13             18    590.549
# 1           70              16             17    363.000
# 2           84              15             18    375.700
# 3           88              13             22  1.045.246
# 4          140              16             26    768.607

# %%
# display the dimension of the cups data
cups.shape
# Out:
# (20, 10)

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37784 entries, 0 to 37783
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   RoundID        37784 non-null  int64
#  1   MatchID        37784 non-null  int64
#  2   Team Initials  37784 non-null  object
#  3   Coach Name     37784 non-null  object
#  4   Line-up        37784 non-null  object
#  5   Shirt Number   37784 non-null  int64
#  6   Player Name    37784 non-null  object
#  7   Position       4143 non-null   object
#  8   Event          9069 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 2.6+ MB

# %%
matches.dtypes
# Out:
# Year                    float64
# Datetime                 object
# Stage                    object
# Stadium                  object
# City                     object
# Home Team Name           object
# Home Team Goals         float64
# Away Team Goals         float64
# Away Team Name           object
# Win conditions           object
# Attendance              float64
# Half-time Home Goals    float64
# Half-time Away Goals    float64
# Referee                  object
# Assistant 1              object
# Assistant 2              object
# RoundID                 float64
# MatchID                 float64
# Home Team Initials       object
# Away Team Initials       object
# dtype: object

# %%
players.describe(include = 'all')
# Out:
#              RoundID       MatchID Team Initials                 Coach Name  \
# count   3.778400e+04  3.778400e+04         37784                      37784
# unique           NaN           NaN            82                        335
# top              NaN           NaN           BRA  SCOLARI Luiz Felipe (BRA)
# freq             NaN           NaN          2403                        575
# mean    1.105647e+07  6.362233e+07           NaN                        NaN
# std     2.770144e+07  1.123916e+08           NaN                        NaN
# min     2.010000e+02  2.500000e+01           NaN                        NaN
# 25%     2.630000e+02  1.199000e+03           NaN                        NaN
# 50%     3.370000e+02  2.216000e+03           NaN                        NaN
# 75%     2.559310e+05  9.741000e+07           NaN                        NaN
# max     9.741060e+07  3.001865e+08           NaN                        NaN
#
#        Line-up  Shirt Number Player Name Position  Event
# count    37784  37784.000000       37784     4143   9069
# unique       2           NaN        7663        3   1893
# top          N           NaN     RONALDO       GK  OH46'
# freq     19040           NaN          33     2441    247
# mean       NaN     10.726022         NaN      NaN    NaN
# std        NaN      6.960138         NaN      NaN    NaN
# min        NaN      0.000000         NaN      NaN    NaN
# 25%        NaN      5.000000         NaN      NaN    NaN
# 50%        NaN     11.000000         NaN      NaN    NaN
# 75%        NaN     17.000000         NaN      NaN    NaN
# max        NaN     23.000000         NaN      NaN    NaN

# %%
matches.describe(include = 'all')
# Out:
#                Year              Datetime        Stage         Stadium  \
# count    852.000000                   852          852             852
# unique          NaN                   602           23             181
# top             NaN  27 May 1934 - 16:30   Round of 16  Estadio Azteca
# freq            NaN                     8           72              19
# mean    1985.089202                   NaN          NaN             NaN
# std       22.448825                   NaN          NaN             NaN
# min     1930.000000                   NaN          NaN             NaN
# 25%     1970.000000                   NaN          NaN             NaN
# 50%     1990.000000                   NaN          NaN             NaN
# 75%     2002.000000                   NaN          NaN             NaN
# max     2014.000000                   NaN          NaN             NaN
#
#                 City Home Team Name  Home Team Goals  Away Team Goals  \
# count            852            852       852.000000       852.000000
# unique           151             78              NaN              NaN
# top     Mexico City          Brazil              NaN              NaN
# freq              23             82              NaN              NaN
# mean             NaN            NaN         1.811033         1.022300
# std              NaN            NaN         1.610255         1.087573
# min              NaN            NaN         0.000000         0.000000
# 25%              NaN            NaN         1.000000         0.000000
# 50%              NaN            NaN         2.000000         1.000000
# 75%              NaN            NaN         3.000000         2.000000
# max              NaN            NaN        10.000000         7.000000
#
#        Away Team Name Win conditions     Attendance  Half-time Home Goals  \
# count             852            852     850.000000            852.000000
# unique             83             43            NaN                   NaN
# top            Mexico                           NaN                   NaN
# freq               38            787            NaN                   NaN
# mean              NaN            NaN   45164.800000              0.708920
# std               NaN            NaN   23485.249247              0.937414
# min               NaN            NaN    2000.000000              0.000000
# 25%               NaN            NaN   30000.000000              0.000000
# 50%               NaN            NaN   41579.500000              0.000000
# 75%               NaN            NaN   61374.500000              1.000000
# max               NaN            NaN  173850.000000              6.000000
#
#         Half-time Away Goals                Referee           Assistant 1  \
# count             852.000000                    852                   852
# unique                   NaN                    366                   387
# top                      NaN  Ravshan IRMATOV (UZB)  ACHIK Redouane (MAR)
# freq                     NaN                     10                     7
# mean                0.428404                    NaN                   NaN
# std                 0.691252                    NaN                   NaN
# min                 0.000000                    NaN                   NaN
# 25%                 0.000000                    NaN                   NaN
# 50%                 0.000000                    NaN                   NaN
# 75%                 1.000000                    NaN                   NaN
# max                 5.000000                    NaN                   NaN
#
#                      Assistant 2       RoundID       MatchID  \
# count                        852  8.520000e+02  8.520000e+02
# unique                       408           NaN           NaN
# top     KOCHKAROV Bakhadyr (KGZ)           NaN           NaN
# freq                          10           NaN           NaN
# mean                         NaN  1.066177e+07  6.134687e+07
# std                          NaN  2.729613e+07  1.110572e+08
# min                          NaN  2.010000e+02  2.500000e+01
# 25%                          NaN  2.620000e+02  1.188750e+03
# 50%                          NaN  3.370000e+02  2.191000e+03
# 75%                          NaN  2.497220e+05  4.395006e+07
# max                          NaN  9.741060e+07  3.001865e+08
#
#        Home Team Initials Away Team Initials
# count                 852                852
# unique                 77                 82
# top                   BRA                MEX
# freq                   82                 38
# mean                  NaN                NaN
# std                   NaN                NaN
# min                   NaN                NaN
# 25%                   NaN                NaN
# 50%                   NaN                NaN
# 75%                   NaN                NaN
# max                   NaN                NaN

# %%
cups.describe(include='all')
# Out:
#                Year Country  Winner Runners-Up    Third   Fourth  GoalsScored  \
# count     20.000000      20      20         20       20       20    20.000000
# unique          NaN      15       9         10       14       16          NaN
# top             NaN   Italy  Brazil  Argentina  Germany  Uruguay          NaN
# freq            NaN       2       5          3        3        3          NaN
# mean    1974.800000     NaN     NaN        NaN      NaN      NaN   118.950000
# std       25.582889     NaN     NaN        NaN      NaN      NaN    32.972836
# min     1930.000000     NaN     NaN        NaN      NaN      NaN    70.000000
# 25%     1957.000000     NaN     NaN        NaN      NaN      NaN    89.000000
# 50%     1976.000000     NaN     NaN        NaN      NaN      NaN   120.500000
# 75%     1995.000000     NaN     NaN        NaN      NaN      NaN   145.250000
# max     2014.000000     NaN     NaN        NaN      NaN      NaN   171.000000
#
#         QualifiedTeams  MatchesPlayed Attendance
# count        20.000000      20.000000         20
# unique             NaN            NaN         20
# top                NaN            NaN    590.549
# freq               NaN            NaN          1
# mean         21.250000      41.800000        NaN
# std           7.268352      17.218717        NaN
# min          13.000000      17.000000        NaN
# 25%          16.000000      30.500000        NaN
# 50%          16.000000      38.000000        NaN
# 75%          26.000000      55.000000        NaN
# max          32.000000      64.000000        NaN

# %%
players.isnull().sum()
# Out:
# RoundID              0
# MatchID              0
# Team Initials        0
# Coach Name           0
# Line-up              0
# Shirt Number         0
# Player Name          0
# Position         33641
# Event            28715
# dtype: int64

# %%
# Checking for missing values in data set by column

def missing_check(df):
 #   count = df.shape[0]   #alternatively  df.isnull().count() or len(df)

    total_sorted = df.isnull().sum().sort_values(ascending = False)
    percent = round((100*total_sorted/len(df)),2) # percentage of values that are null
    
 #   missing_data = pd.concat([total_sorted,percent], axis=1, keys=['Total','%'])
  #  print('count is ', count)
  #  print('total is \n', total)
    
    return pd.concat([total_sorted,percent], axis=1, keys=['Total','%'])
missing_check(players)
# Out:
#                Total      %
# Position       33641  89.04
# Event          28715  76.00
# RoundID            0   0.00
# MatchID            0   0.00
# Team Initials      0   0.00
# Coach Name         0   0.00
# Line-up            0   0.00
# Shirt Number       0   0.00
# Player Name        0   0.00

# %%
players.Position.value_counts()
# Out:
# GK     2441
# C      1510
# GKC     192
# Name: Position, dtype: int64

# %%
players.Position.replace('', np.NaN)
# Out:
# 0         GK
# 1         GK
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 37779    NaN
# 37780    NaN
# 37781    NaN
# 37782    NaN
# 37783    NaN
# Name: Position, Length: 37784, dtype: object

# %%
df = players['Position'].value_counts().index[0]
df
# Out:
# 'GK'

# %%
players['Position'].fillna(df,inplace=True)  #fill all the 'NaN's with the value of index[0]
players["Position"]
# Out:
# 0        GK
# 1        GK
# 2        GK
# 3        GK
# 4        GK
#          ..
# 37779    GK
# 37780    GK
# 37781    GK
# 37782    GK
# 37783    GK
# Name: Position, Length: 37784, dtype: object

# %%
players.Event.value_counts()
# Out:
# OH46'              247
# IH46'              206
# Y1'                 87
# I77'                78
# I78'                78
#                   ...
# Y58' G59' G81'       1
# P4'                  1
# Y1' Y49' RSY49'      1
# G18' G84'            1
# G60' O83'            1
# Name: Event, Length: 1893, dtype: int64

# %%
players.Event.replace('', np.NaN)
# Out:
# 0               NaN
# 1               NaN
# 2              G40'
# 3              G70'
# 4               NaN
#             ...
# 37779           NaN
# 37780           NaN
# 37781    IH46' Y65'
# 37782           NaN
# 37783           NaN
# Name: Event, Length: 37784, dtype: object

# %%
df1 = players['Event'].value_counts().index[0]
players['Event'].fillna(df1,inplace=True)
players["Event"].head()
# Out:
# 0    OH46'
# 1    OH46'
# 2     G40'
# 3     G70'
# 4    OH46'
# Name: Event, dtype: object

# %%
missing_check(players)
# Out:
#                Total    %
# RoundID            0  0.0
# MatchID            0  0.0
# Team Initials      0  0.0
# Coach Name         0  0.0
# Line-up            0  0.0
# Shirt Number       0  0.0
# Player Name        0  0.0
# Position           0  0.0
# Event              0  0.0

# %%
cups.corr()
# Out:
#                     Year  GoalsScored  QualifiedTeams  MatchesPlayed
# Year            1.000000     0.829886        0.895565       0.972473
# GoalsScored     0.829886     1.000000        0.866201       0.876201
# QualifiedTeams  0.895565     0.866201        1.000000       0.949164
# MatchesPlayed   0.972473     0.876201        0.949164       1.000000

# %%
# To get a correlation matrix
# Ploting correlation plot
f,ax = plt.subplots(figsize=(10,5))

# plotting the heat map
# corr: give the correlation matrix
# cmap: colour code used for plotting
# vmax: gives maximum range of values for the chart
# vmin: gives minimum range of values for the chart
# annot: prints the correlation values in the chart
# annot_kws={"size": 12}): Sets the font size of the annotation

sns.heatmap(cups.corr(), annot=True, linewidths=.3, fmt= '.3f',ax=ax)
# specify name of the plot
plt.title('Correlation between features')
plt.show()

# %%
#plt.figure(figsize=(15,8))
matches.boxplot(column = 'Home Team Goals', by = 'Away Team Goals', color='r')
#plt.title('Home Team Goals')
#plt.show()
# Out:
# <AxesSubplot:title={'center':'Home Team Goals'}, xlabel='Away Team Goals'>

# %%
matches["total_goals"] = matches["Home Team Goals"] + matches["Away Team Goals"]

plt.figure(figsize=(15,8))
sns.boxplot(y=matches["total_goals"],
            x=matches["Year"])
plt.grid(True)
plt.title("Total goals scored during game by year",color='r')
plt.show()

# %%
Q1 = matches.quantile(0.25)
Q3 = matches.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Year                          32.0
# Home Team Goals                2.0
# Away Team Goals                2.0
# Attendance                 31374.5
# Half-time Home Goals           1.0
# Half-time Away Goals           1.0
# RoundID                   249460.0
# MatchID                 43948870.5
# total_goals                    3.0
# dtype: float64

# %%
matches = matches[~((matches < (Q1 - 1.5 * IQR)) |(matches > (Q3 + 1.5 * IQR))).any(axis=1)]
#removing outliers as defined as 1.5 * IQR

# %%
matches.boxplot(column='Home Team Goals',by = 'Away Team Goals', color='b')
# Out:
# <AxesSubplot:title={'center':'Home Team Goals'}, xlabel='Away Team Goals'>

# %%
matches["total_goals"] = matches["Home Team Goals"] + matches["Away Team Goals"]

plt.figure(figsize=(15,8))
sns.boxplot(y=matches["total_goals"],
            x=matches["Year"])
plt.grid(True)
plt.title("Total goals scored during game by year",color='b')
plt.show()

# %%
sns.distplot(cups.Year)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Density'>

# %%
plt.figure(figsize=(15, 4))
sns.countplot(cups.Country, order = cups.Country.value_counts().index);

# %%
cups.plot(kind='scatter',x='Year', y='GoalsScored', alpha = .8, color = 'red', figsize= (6,6))
plt.xlabel("Year")
plt.ylabel('Goas Scored')
plt.show()

# %%
ax = plt.gca()

cups.plot(kind='line', x = "Year",y = "GoalsScored", color = "green", ax=ax,grid = True,figsize = (7,7))
cups.plot(kind='line', x = "Year",y = "MatchesPlayed", color = 'red', ax=ax,grid = True)
cups.plot(kind='line', x = "Year",y = "QualifiedTeams", color = 'b', ax=ax,grid = True)
plt.legend(loc = "upper left")
plt.show()

# %%
sns.lmplot(x='Year', y='GoalsScored', hue='Country', 
           data=cups, 
           fit_reg=False)

# %%
data=cups.loc[cups['Country'].isin(
    ['Uruguay', 'Italy', 'France', 'Brazil', 'Switzerland', 'Chile', 'England', 'Mexico', 'Germany', 'Argentina', 'Spain', 'Mexico'])
             ] 
data
# Out:
#     Year      Country      Winner      Runners-Up        Third        Fourth  \
# 0   1930      Uruguay     Uruguay       Argentina          USA    Yugoslavia
# 1   1934        Italy       Italy  Czechoslovakia      Germany       Austria
# 2   1938       France       Italy         Hungary       Brazil        Sweden
# 3   1950       Brazil     Uruguay          Brazil       Sweden         Spain
# 4   1954  Switzerland  Germany FR         Hungary      Austria       Uruguay
# 6   1962        Chile      Brazil  Czechoslovakia        Chile    Yugoslavia
# 7   1966      England     England      Germany FR     Portugal  Soviet Union
# 8   1970       Mexico      Brazil           Italy   Germany FR       Uruguay
# 9   1974      Germany  Germany FR     Netherlands       Poland        Brazil
# 10  1978    Argentina   Argentina     Netherlands       Brazil         Italy
# 11  1982        Spain       Italy      Germany FR       Poland        France
# 12  1986       Mexico   Argentina      Germany FR       France       Belgium
# 13  1990        Italy  Germany FR       Argentina        Italy       England
# 15  1998       France      France          Brazil      Croatia   Netherlands
# 17  2006      Germany       Italy          France      Germany      Portugal
# 19  2014       Brazil     Germany       Argentina  Netherlands        Brazil
#
#     GoalsScored  QualifiedTeams  MatchesPlayed Attendance
# 0            70              13             18    590.549
# 1            70              16             17    363.000
# 2            84              15             18    375.700
# 3            88              13             22  1.045.246
# 4           140              16             26    768.607
# 6            89              16             32    893.172
# 7            89              16             32  1.563.135
# 8            95              16             32  1.603.975
# 9            97              16             38  1.865.753
# 10          102              16             38  1.545.791
# 11          146              24             52  2.109.723
# 12          132              24             52  2.394.031
# 13          115              24             52  2.516.215
# 15          171              32             64  2.785.100
# 17          147              32             64  3.359.439
# 19          171              32             64  3.386.810

# %%
f,ax = plt.subplots(figsize=(15, 5))
sns.heatmap(cups.corr(), annot=True, linewidths=.5, fmt= '.4f',ax=ax)
plt.show()

# %%
cups[np.logical_and(cups['GoalsScored']>100, cups['Year']>1930 )]
# Out:
#     Year       Country      Winner   Runners-Up        Third          Fourth  \
# 4   1954   Switzerland  Germany FR      Hungary      Austria         Uruguay
# 5   1958        Sweden      Brazil       Sweden       France      Germany FR
# 10  1978     Argentina   Argentina  Netherlands       Brazil           Italy
# 11  1982         Spain       Italy   Germany FR       Poland          France
# 12  1986        Mexico   Argentina   Germany FR       France         Belgium
# 13  1990         Italy  Germany FR    Argentina        Italy         England
# 14  1994           USA      Brazil        Italy       Sweden        Bulgaria
# 15  1998        France      France       Brazil      Croatia     Netherlands
# 16  2002   Korea/Japan      Brazil      Germany       Turkey  Korea Republic
# 17  2006       Germany       Italy       France      Germany        Portugal
# 18  2010  South Africa       Spain  Netherlands      Germany         Uruguay
# 19  2014        Brazil     Germany    Argentina  Netherlands          Brazil
#
#     GoalsScored  QualifiedTeams  MatchesPlayed Attendance
# 4           140              16             26    768.607
# 5           126              16             35    819.810
# 10          102              16             38  1.545.791
# 11          146              24             52  2.109.723
# 12          132              24             52  2.394.031
# 13          115              24             52  2.516.215
# 14          141              24             52  3.587.538
# 15          171              32             64  2.785.100
# 16          161              32             64  2.705.197
# 17          147              32             64  3.359.439
# 18          145              32             64  3.178.856
# 19          171              32             64  3.386.810

# %%
# Return a list of top X cups that finished with the most goals (default:5) 

def cup(count = 5):
    ecg = cups.sort_values(by=['GoalsScored'],ascending=False).head(count)
    return ecg
cup()
# Out:
#     Year      Country   Winner  Runners-Up        Third          Fourth  \
# 19  2014       Brazil  Germany   Argentina  Netherlands          Brazil
# 15  1998       France   France      Brazil      Croatia     Netherlands
# 16  2002  Korea/Japan   Brazil     Germany       Turkey  Korea Republic
# 17  2006      Germany    Italy      France      Germany        Portugal
# 11  1982        Spain    Italy  Germany FR       Poland          France
#
#     GoalsScored  QualifiedTeams  MatchesPlayed Attendance
# 19          171              32             64  3.386.810
# 15          171              32             64  2.785.100
# 16          161              32             64  2.705.197
# 17          147              32             64  3.359.439
# 11          146              24             52  2.109.723

# %%
# Avg goals per match by host country

def goals(country = 16):
    Country = cups.at[country-1,'Country']
    year = cups.at[country-1,'Year']
    goals = cups.at[country-1,'GoalsScored']
    matches = cups.at[country-1,'MatchesPlayed']
    
    def AvgGoal(goals, matches):
        avg = round(goals/matches,1)
        return avg
    print('Host Country/Year: ',Country,'/',year)
    print("Avg goal per match:", AvgGoal(goals,matches))
    
goals(10)
# Out:
# Host Country/Year:  Germany / 1974
# Avg goal per match: 2.6

# %%
# Total goals by year

plt.figure(figsize=(15,5))
cups["Year1"] = cups["Year"].astype(str)
ax = plt.scatter("Year1","GoalsScored",data=cups,
            c=cups["GoalsScored"],cmap="inferno",
            s=100,alpha=.7,
            linewidth=2,edgecolor="k")

#plt.colorbar()
plt.xticks(cups["Year1"].unique())
plt.yticks(np.arange(60,200,20))
plt.title('Total goals scored by year',color='b')
plt.xlabel("Year")
plt.ylabel("Total goals scored")
plt.show()

# %%
plt.figure(figsize=(12,7))
# edgecolor=[c for c in "k"*len(cups)],

sns.barplot(cups["Year"],cups["MatchesPlayed"],linewidth=1,
            color="b",label="Total matches played")

sns.barplot(cups["Year"],cups["QualifiedTeams"],linewidth=1,
            color="r",label="Total qualified teams")

plt.legend(loc="best",prop={"size":13})
#plt.title("Qualified teams by year", color='b')
plt.grid(True)
plt.ylabel("Total matches played | Qualified teams by year")
plt.show()

# %% [markdown]
# # Matches with most attendance

# %%
matches = matches.dropna()
matches.head()
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# 5  1930.0  16 Jul 1930 - 14:45   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
# 5          Chile              3.0              0.0         Mexico
#
#   Win conditions  ...  Half-time Home Goals  Half-time Away Goals  \
# 1                 ...                   2.0                   0.0
# 2                 ...                   2.0                   0.0
# 3                 ...                   1.0                   0.0
# 4                 ...                   0.0                   0.0
# 5                 ...                   1.0                   0.0
#
#                  Referee               Assistant 1  \
# 1      MACIAS Jose (ARG)  MATEUCCI Francisco (URU)
# 2    TEJADA Anibal (URU)   VALLARINO Ricardo (URU)
# 3  WARNKEN Alberto (CHI)       LANGENUS Jean (BEL)
# 4    REGO Gilberto (BRA)      SAUCEDO Ulises (BOL)
# 5  CRISTOPHE Henry (BEL)   APHESTEGUY Martin (URU)
#
#                   Assistant 2 RoundID  MatchID  Home Team Initials  \
# 1       WARNKEN Alberto (CHI)   201.0   1090.0                 USA
# 2         BALWAY Thomas (FRA)   201.0   1093.0                 YUG
# 3    MATEUCCI Francisco (URU)   201.0   1098.0                 ROU
# 4  RADULESCU Constantin (ROU)   201.0   1085.0                 ARG
# 5         LANGENUS Jean (BEL)   201.0   1095.0                 CHI
#
#   Away Team Initials total_goals
# 1                BEL         3.0
# 2                BRA         3.0
# 3                PER         4.0
# 4                FRA         1.0
# 5                MEX         3.0
#
# [5 rows x 21 columns]

# %%
h_att = matches.sort_values(by="Attendance",ascending=False)[:10]
h_att["Stadium"] = h_att["Stadium"].replace('Maracan� - Est�dio Jornalista M�rio Filho',"Maracanã Stadium")
h_att["Datetime"] = h_att["Datetime"].str.split("-").str[0]
h_att['HomeTeamName'] = h_att['Home Team Name']
h_att['AwayTeamName'] = h_att['Away Team Name']

h_att["mt"] = h_att["HomeTeamName"] + " vs. " + h_att["AwayTeamName"]

plt.figure(figsize=(10,9))
ax = sns.barplot(y = h_att["mt"], x = h_att["Attendance"], palette="gist_ncar",
                 linewidth = 1, edgecolor=[c for c in "k"*len(h_att)])
#plt.ylabel("match teams")
plt.xlabel("Attendance")
plt.title("Matches with largest attendance", color='b')
plt.grid(False)

for i,j in enumerate("  "+ h_att["Stadium"] + ", " + h_att["Datetime"]):
    ax.text(.7,i,j,fontsize = 12,color="white",weight = "bold")
    
plt.show()
#h_att["mt"] = h_att["HomeTeamName"] + " .Vs.  " + h_att["AwayTeamName"]
