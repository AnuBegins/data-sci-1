# %%
import warnings
warnings.filterwarnings('ignore')     # to avoid warning messages

# %%
# !pip install plotly 
# !pip install community 
# !pip install python-louvain
# !pip install colorlover
# Out:
# Collecting plotly
#   Downloading plotly-5.12.0-py2.py3-none-any.whl (15.2 MB)
#      |████████████████████████████████| 15.2 MB 668 kB/s eta 0:00:01
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.1.0-py3-none-any.whl (23 kB)
# Installing collected packages: tenacity, plotly
# Successfully installed plotly-5.12.0 tenacity-8.1.0
# Collecting community
#   Downloading community-1.0.0b1.tar.gz (2.2 kB)
# Requirement already satisfied: Flask in /Users/ArunRam/opt/anaconda3/lib/python3.9/site-packages (from community) (1.1.2)
# Requirement already satisfied: requests in /Users/ArunRam/opt/anaconda3/lib/python3.9/site-packages (from community) (2.26.0)
# Requirement already satisfied: Jinja2>=2.10.1 in /Users/ArunRam/opt/anaconda3/lib/python3.9/site-packages (from Flask->community) (2.11.3)
# Requirement already satisfied: itsdangerous>=0.24 in /Users/ArunRam/opt/anaconda3/lib/python3.9/site-packages (from Flask->community) (2.0.1)
# Requirement already satisfied: Werkzeug>=0.15 in /Users/ArunRam/opt/anaconda3/lib/python3.9/site-packages (from Flask->community) (2.0.2)
# Requirement already satisfied: click>=5.1 in /Users/ArunRam/opt/anaconda3/lib/python3.9/site-packages (from Flask->community) (8.0.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/ArunRam/opt/anaconda3/lib/python3.9/site-packages (from Jinja2>=2.10.1->Flask->community) (1.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ArunRam/opt/anaconda3/lib/python3.9/site-packages (from requests->community) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ArunRam/opt/anaconda3/lib/python3.9/site-packages (from requests->community) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/ArunRam/opt/anaconda3/lib/python3.9/site-packages (from requests->community) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/ArunRam/opt/anaconda3/lib/python3.9/site-packages (from requests->community) (2.0.4)
# Building wheels for collected packages: community
#   Building wheel for community (setup.py) ... done
#   Created wheel for community: filename=community-1.0.0b1-py3-none-any.whl size=2153 sha256=8cf4efeedfc974f2cce734f064a76d8a075e0e706004d7381869647b4b0d9476
#   Stored in directory: /Users/ArunRam/Library/Caches/pip/wheels/e5/32/7b/aebaa96975f39189b78d7b123cf90e5fd2f0418953833b3043
# Successfully built community
# Installing collected packages: community
# Successfully installed community-1.0.0b1
# Collecting python-louvain
#   Downloading python-louvain-0.16.tar.gz (204 kB)
#      |████████████████████████████████| 204 kB 589 kB/s eta 0:00:01
# Requirement already satisfied: networkx in /Users/ArunRam/opt/anaconda3/lib/python3.9/site-packages (from python-louvain) (2.6.3)
# Requirement already satisfied: numpy in /Users/ArunRam/opt/anaconda3/lib/python3.9/site-packages (from python-louvain) (1.20.3)
# Building wheels for collected packages: python-louvain
#   Building wheel for python-louvain (setup.py) ... done
#   Created wheel for python-louvain: filename=python_louvain-0.16-py3-none-any.whl size=9407 sha256=c1e902052193a29d57ea7237d572da9702a8db9d87583d83c154dfe99e283fe6
#   Stored in directory: /Users/ArunRam/Library/Caches/pip/wheels/4d/7c/b6/79b198e4ec43f915fbdf967953d48b89a18893b12aa9df0ae2
# Successfully built python-louvain
# Installing collected packages: python-louvain
# Successfully installed python-louvain-0.16
# Collecting colorlover
#   Downloading colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# Installing collected packages: colorlover
# Successfully installed colorlover-0.3.0

# %%
# %matplotlib inline

import networkx as nx

from decorator import decorator

from networkx.utils import create_random_state, create_py_random_state

import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

import seaborn as sns

import os

# Remove scientific notations and display numbers with 2 decimal points instead
pd.options.display.float_format = '{:,.2f}'.format        

# Update default background style of plots
sns.set_style(style='darkgrid')

from plotly.offline import download_plotlyjs, init_notebook_mode, iplot

import plotly.graph_objs as go

import plotly

import plotly.express as px
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.17.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
os.listdir("raw_data_books/")
# Out:
# ['book1.csv', 'book2.csv', 'book3.csv', 'book4.csv', 'book5.csv']

# %%
book1 = pd.read_csv("raw_data_books/book1.csv")

# %%
book1.shape
# Out:
# (684, 5)

# %%
book1.head()
# Out:
#                           Person 1            Person 2        Type  weight  \
# 0                   Addam-Marbrand     Jaime-Lannister  Undirected       3
# 1                   Addam-Marbrand     Tywin-Lannister  Undirected       6
# 2                Aegon-I-Targaryen  Daenerys-Targaryen  Undirected       5
# 3                Aegon-I-Targaryen        Eddard-Stark  Undirected       4
# 4  Aemon-Targaryen-(Maester-Aemon)      Alliser-Thorne  Undirected       4
#
#    book
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1

# %%
book2 = pd.read_csv("raw_data_books/book2.csv")

book3 = pd.read_csv("raw_data_books/book3.csv")

book4 = pd.read_csv("raw_data_books/book4.csv")

book5 = pd.read_csv("raw_data_books/book5.csv")

# %%
books = [book1, book2, book3, book4, book5]

books_combined = pd.DataFrame()

for book in books:
    books_combined = pd.concat([books_combined, book])

# Grouping the data by Person 2 and Person 1 to avoid multiple entries with the same characters 
books_combined = books_combined.groupby(["Person 2", "Person 1"], as_index = False)["weight"].sum()

# %%
# DESCRIPTIVE ANALYTICS

books_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Person 2  2823 non-null   object
#  1   Person 1  2823 non-null   object
#  2   weight    2823 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 66.3+ KB

# %%
books_combined.describe()
# Out:
#         weight
# count 2,823.00
# mean     11.56
# std      19.98
# min       3.00
# 25%       3.00
# 50%       5.00
# 75%      11.00
# max     334.00

# %%
# OBSERVATIONS

# There are **2823 edges** in total, or 2823 co-occurrences of characters.
#The **minimum weight is 3** (meaning every co-occurrence pair has been observed at least thrice), and the **maximum weight is 334**.
# The **mean weight is 11.56**, meaning that on average, two co-occurring characters are mentioned around 12 times together. **The median of 5** also implies that **it is the maximum weight which is more likely the outlier,** which is also affirmed by the fact that 75% of the weight values are 11 or lower.

# %%
books_combined[books_combined["weight"] == 334]
# Out:
#               Person 2      Person 1  weight
# 1570  Robert-Baratheon  Eddard-Stark     334

# %% [markdown]
# ## **Creating a Graph Network (for each book as well as all books combined)**

# %%
G1 = nx.from_pandas_edgelist(book1, 'Person 1', "Person 2", edge_attr = "weight", create_using = nx.Graph())

G2 = nx.from_pandas_edgelist(book2, 'Person 1', "Person 2", edge_attr = "weight", create_using = nx.Graph())

G3 = nx.from_pandas_edgelist(book3, 'Person 1', "Person 2", edge_attr = "weight", create_using = nx.Graph())

G4 = nx.from_pandas_edgelist(book4, 'Person 1', "Person 2", edge_attr = "weight", create_using = nx.Graph())

G5 = nx.from_pandas_edgelist(book5, 'Person 1', "Person 2", edge_attr = "weight", create_using = nx.Graph())

G = nx.from_pandas_edgelist(books_combined, 'Person 1', "Person 2", edge_attr = "weight", create_using = nx.Graph())

# %%
# Number of nodes & edges in combined graph network

nx.info(G)
#print(list(G.degree()),'\n')
sorted(list(G.degree()), key = lambda x:x[1], reverse = True)
# Out:
# [('Tyrion-Lannister', 122),
#  ('Jon-Snow', 114),
#  ('Jaime-Lannister', 101),
#  ('Cersei-Lannister', 97),
#  ('Stannis-Baratheon', 89),
#  ('Arya-Stark', 84),
#  ('Catelyn-Stark', 75),
#  ('Sansa-Stark', 75),
#  ('Eddard-Stark', 74),
#  ('Robb-Stark', 74),
#  ('Daenerys-Targaryen', 73),
#  ('Joffrey-Baratheon', 69),
#  ('Theon-Greyjoy', 66),
#  ('Robert-Baratheon', 65),
#  ('Bran-Stark', 54),
#  ('Tywin-Lannister', 48),
#  ('Petyr-Baelish', 47),
#  ('Brienne-of-Tarth', 45),
#  ('Samwell-Tarly', 44),
#  ('Barristan-Selmy', 41),
#  ('Renly-Baratheon', 38),
#  ('Sandor-Clegane', 36),
#  ('Varys', 34),
#  ('Davos-Seaworth', 33),
#  ('Gregor-Clegane', 33),
#  ('Mance-Rayder', 33),
#  ('Tommen-Baratheon', 33),
#  ('Margaery-Tyrell', 30),
#  ('Rodrik-Cassel', 30),
#  ('Jeor-Mormont', 28),
#  ('Loras-Tyrell', 28),
#  ('Roose-Bolton', 28),
#  ('Pycelle', 27),
#  ('Aemon-Targaryen-(Maester-Aemon)', 26),
#  ('Jorah-Mormont', 26),
#  ('Asha-Greyjoy', 25),
#  ('Bronn', 25),
#  ('Edmure-Tully', 24),
#  ('Lysa-Arryn', 24),
#  ('Victarion-Greyjoy', 24),
#  ('Janos-Slynt', 23),
#  ('Mace-Tyrell', 23),
#  ('Melisandre', 23),
#  ('Ramsay-Snow', 23),
#  ('Hizdahr-zo-Loraq', 22),
#  ('Ilyn-Payne', 22),
#  ('Luwin', 22),
#  ('Myrcella-Baratheon', 22),
#  ('Doran-Martell', 21),
#  ('Drogo', 21),
#  ('Jory-Cassel', 21),
#  ('Meryn-Trant', 21),
#  ('Arianne-Martell', 20),
#  ('Amory-Lorch', 20),
#  ('Eddison-Tollett', 20),
#  ('Gendry', 20),
#  ('Oberyn-Martell', 20),
#  ('Robert-Arryn', 20),
#  ('Aerys-II-Targaryen', 19),
#  ('Brynden-Tully', 19),
#  ('Daario-Naharis', 19),
#  ('Quentyn-Martell', 19),
#  ('Selyse-Florent', 19),
#  ('Walder-Frey', 19),
#  ('Beric-Dondarrion', 18),
#  ('Bowen-Marsh', 18),
#  ('Gyles-Rosby', 18),
#  ('Osmund-Kettleblack', 18),
#  ('Qyburn', 18),
#  ('Rhaegar-Targaryen', 18),
#  ('Yoren', 18),
#  ('Jon-Arryn', 17),
#  ('Kevan-Lannister', 17),
#  ('Rickon-Stark', 17),
#  ('Wyman-Manderly', 17),
#  ('Balon-Swann', 16),
#  ('Jon-Connington', 16),
#  ('Pypar', 16),
#  ('Alliser-Thorne', 15),
#  ('Aeron-Greyjoy', 15),
#  ('Craster', 15),
#  ('Aegon-Targaryen-(son-of-Rhaegar)', 15),
#  ('Grenn', 15),
#  ('Irri', 15),
#  ('Lem', 15),
#  ('Tormund', 15),
#  ('Benjen-Stark', 14),
#  ('Boros-Blount', 14),
#  ('Gilly', 14),
#  ('Jon-Umber-(Greatjon)', 14),
#  ('Polliver', 14),
#  ('Qhorin-Halfhand', 14),
#  ('Viserys-Targaryen', 14),
#  ('Balon-Greyjoy', 13),
#  ('Belwas', 13),
#  ('Chiswyck', 13),
#  ('Dunsen', 13),
#  ('Euron-Greyjoy', 13),
#  ('Jeyne-Poole', 13),
#  ('Rafford', 13),
#  ('Randyll-Tarly', 13),
#  ('Satin', 13),
#  ('Shae', 13),
#  ('Shireen-Baratheon', 13),
#  ('Ygritte', 13),
#  ('Addam-Marbrand', 12),
#  ('Illyrio-Mopatis', 12),
#  ('Jhiqui', 12),
#  ('Jhogo', 12),
#  ('Lancel-Lannister', 12),
#  ('Rickard-Karstark', 12),
#  ('Ryman-Frey', 12),
#  ('Skahaz-mo-Kandaq', 12),
#  ('Taena-of-Myr', 12),
#  ('Tickler', 12),
#  ('Haldon', 11),
#  ('Hareth-(Moles-Town)', 11),
#  ('Harwin', 11),
#  ('Hobb', 11),
#  ('Hodor', 11),
#  ('Hot-Pie', 11),
#  ('Lothar-Frey', 11),
#  ('Meera-Reed', 11),
#  ('Mordane', 11),
#  ('Osney-Kettleblack', 11),
#  ('Othell-Yarwyck', 11),
#  ('Podrick-Payne', 11),
#  ('Rattleshirt', 11),
#  ('Axell-Florent', 10),
#  ('Aggo', 10),
#  ('Cotter-Pyke', 10),
#  ('Hoster-Tully', 10),
#  ('Jojen-Reed', 10),
#  ('Orton-Merryweather', 10),
#  ('Owen', 10),
#  ('Rakharo', 10),
#  ('Vargo-Hoat', 10),
#  ('Areo-Hotah', 9),
#  ('Anguy', 9),
#  ('Arys-Oakheart', 9),
#  ('Ben-Plumm', 9),
#  ('Aurane-Waters', 9),
#  ('Aegon-I-Targaryen', 9),
#  ('Cressen', 9),
#  ('Denys-Mallister', 9),
#  ('Dontos-Hollard', 9),
#  ('Elia-Martell', 9),
#  ('Elmar-Frey', 9),
#  ('Garin-(orphan)', 9),
#  ('Gerris-Drinkwater', 9),
#  ('Harys-Swyft', 9),
#  ('Jacelyn-Bywater', 9),
#  ('Mandon-Moore', 9),
#  ('Marillion', 9),
#  ('Missandei', 9),
#  ('Mully', 9),
#  ('Olenna-Redwyne', 9),
#  ('Osha', 9),
#  ('Rorge', 9),
#  ('Thoren-Smallwood', 9),
#  ('Thoros-of-Myr', 9),
#  ('Tom-of-Sevenstreams', 9),
#  ('Tyene-Sand', 9),
#  ('Val', 9),
#  ('Alleras', 8),
#  ('Arstan', 8),
#  ('Brandon-Stark', 8),
#  ('Donal-Noye', 8),
#  ('Dywen', 8),
#  ('Emmon-Frey', 8),
#  ('Galbart-Glover', 8),
#  ('Gerold-Hightower', 8),
#  ('Grey-Worm', 8),
#  ('Halder', 8),
#  ('High-Sparrow', 8),
#  ('Jarl', 8),
#  ('Harma', 8),
#  ('Lorren', 8),
#  ('Marq-Piper', 8),
#  ('Mathis-Rowan', 8),
#  ('Nan', 8),
#  ('Rolly-Duckfield', 8),
#  ('Styr', 8),
#  ('Tattered-Prince', 8),
#  ('Walder-Frey-(son-of-Merrett)', 8),
#  ('Weese', 8),
#  ('Willas-Tyrell', 8),
#  ('Yohn-Royce', 8),
#  ('Alester-Florent', 7),
#  ('Anya-Waynwood', 7),
#  ('Chett', 7),
#  ('Cleos-Frey', 7),
#  ('Clydas', 7),
#  ('Cortnay-Penrose', 7),
#  ('Donella-Hornwood', 7),
#  ('Garlan-Tyrell', 7),
#  ('Godry-Farring', 7),
#  ('Greenbeard', 7),
#  ('Hyle-Hunt', 7),
#  ('Kegs', 7),
#  ('Lemore', 7),
#  ('Lollys-Stokeworth', 7),
#  ('Nestor-Royce', 7),
#  ('Pate-(novice)', 7),
#  ('Penny', 7),
#  ('Qotho', 7),
#  ('Robett-Glover', 7),
#  ('Rodrik-Harlaw', 7),
#  ('Shagga', 7),
#  ('Tanda-Stokeworth', 7),
#  ('Tomard', 7),
#  ('Wendel-Manderly', 7),
#  ('Yandry', 7),
#  ('Armen', 6),
#  ('Colemon', 6),
#  ('Dareon', 6),
#  ('Devan-Seaworth', 6),
#  ('Dorcas', 6),
#  ('Doreah', 6),
#  ('Edric-Storm', 6),
#  ('Ellaria-Sand', 6),
#  ('Galazza-Galare', 6),
#  ('Dalla', 6),
#  ('Groleo', 6),
#  ('Hagen', 6),
#  ('Haggo', 6),
#  ('Hallis-Mollen', 6),
#  ('Hullen', 6),
#  ('Jaqen-Hghar', 6),
#  ('Barbrey-Dustin', 6),
#  ('Lark', 6),
#  ('Lommy-Greenhands', 6),
#  ('Maegor-I-Targaryen', 6),
#  ('Meris', 6),
#  ('Mirri-Maz-Duur', 6),
#  ('Narbert-Grandison', 6),
#  ('Obara-Sand', 6),
#  ('Paxter-Redwyne', 6),
#  ('Pylos', 6),
#  ('Rast', 6),
#  ('Shagwell', 6),
#  ('Small-Paul', 6),
#  ('Sour-Alyn', 6),
#  ('Spare-Boot', 6),
#  ('Spotted-Cat', 6),
#  ('Sybell-Spicer', 6),
#  ('Tallad', 6),
#  ('Tansy', 6),
#  ('Varamyr', 6),
#  ('Vardis-Egen', 6),
#  ('Willis-Wode', 6),
#  ('Ysilla', 6),
#  ('Andrey-Dalt', 5),
#  ('Arnolf-Karstark', 5),
#  ('Arthur-Dayne', 5),
#  ('Benedar-Belmore', 5),
#  ('Biter', 5),
#  ('Blue-Bard', 5),
#  ('Cletus-Yronwood', 5),
#  ('Bryce-Caron', 5),
#  ('Bedwyck', 5),
#  ('Dagmer', 5),
#  ('Dick-Crabb', 5),
#  ('Alyn', 5),
#  ('Alla-Tyrell', 5),
#  ('Elinor-Tyrell', 5),
#  ('Emmett', 5),
#  ('Gerold-Dayne', 5),
#  ('Caggo', 5),
#  ('Gilwood-Hunter', 5),
#  ('Damon-Dance-for-Me', 5),
#  ('Jack-Bulwer', 5),
#  ('Jalabhar-Xho', 5),
#  ('Jaremy-Rykker', 5),
#  ('Jeyne-Westerling', 5),
#  ('Jocelyn-Swyft', 5),
#  ('Justin-Massey', 5),
#  ('Khrazz', 5),
#  ('Leathers', 5),
#  ('Leo-Tyrell', 5),
#  ('Lothor-Brune', 5),
#  ('Lyanna-Stark', 5),
#  ('Lyle-Crakehall', 5),
#  ('Maddy', 5),
#  ('Maege-Mormont', 5),
#  ('Meribald', 5),
#  ('Mikken', 5),
#  ('Moqorro', 5),
#  ('Mya-Stone', 5),
#  ('Mycah', 5),
#  ('Qezza', 5),
#  ('Quaro', 5),
#  ('Reznak-mo-Reznak', 5),
#  ('Roslin-Frey', 5),
#  ('Rowan', 5),
#  ('Salladhor-Saan', 5),
#  ('Skinner', 5),
#  ('Stevron-Frey', 5),
#  ('Sylva-Santagar', 5),
#  ('Symond-Templeton', 5),
#  ('Tytos-Blackwood', 5),
#  ('Vayon-Poole', 5),
#  ('Walder-Rivers', 5),
#  ('Walton', 5),
#  ('Weeper', 5),
#  ('Wex-Pyke', 5),
#  ('Woth', 5),
#  ('Yezzan-zo-Qaggaz', 5),
#  ('Aenys-Frey', 4),
#  ('Baelor-Blacktyde', 4),
#  ('Bloodbeard', 4),
#  ('Alebelly', 4),
#  ('Alayaya', 4),
#  ('Caleotte', 4),
#  ('Aegon-Frey-(son-of-Stevron)', 4),
#  ('Cellador', 4),
#  ('Archibald-Yronwood', 4),
#  ('Coldhands', 4),
#  ('Benerro', 4),
#  ('Cohollo', 4),
#  ('Desmond-Grell', 4),
#  ('Ebben', 4),
#  ('Edwyn-Frey', 4),
#  ('Falyse-Stokeworth', 4),
#  ('Aggar', 4),
#  ('Belaquo', 4),
#  ('Goghor-the-Giant', 4),
#  ('Gretchel', 4),
#  ('Grimtongue', 4),
#  ('Benfred-Tallhart', 4),
#  ('Helman-Tallhart', 4),
#  ('Hero', 4),
#  ('High-Septon-(Tyrions)', 4),
#  ('Holly', 4),
#  ('Horton-Redfort', 4),
#  ('Hosteen-Frey', 4),
#  ('Hotho-Harlaw', 4),
#  ('Hother-Umber', 4),
#  ('Karyl-Vance', 4),
#  ('Lamprey', 4),
#  ('Lewyn-Martell', 4),
#  ('Lyn-Corbray', 4),
#  ('Malegorn', 4),
#  ('Megga-Tyrell', 4),
#  ('Melara-Hetherspoon', 4),
#  ('Mero', 4),
#  ('Mollander', 4),
#  ('Moon-Boy', 4),
#  ('Mors-Umber', 4),
#  ('Nurse', 4),
#  ('Nute', 4),
#  ('Nymeria-Sand', 4),
#  ('Ottyn-Wythers', 4),
#  ('Patchface', 4),
#  ('Patrek-of-Kings-Mountain', 4),
#  ('Pia', 4),
#  ('Pono', 4),
#  ('Pyg', 4),
#  ('Robert-Strong', 4),
#  ('Roone', 4),
#  ('Ryk', 4),
#  ('Sharna', 4),
#  ('Sigorn', 4),
#  ('Squirrel', 4),
#  ('Stafford-Lannister', 4),
#  ('Stonesnake', 4),
#  ('Syrio-Forel', 4),
#  ('Timeon', 4),
#  ('Timett', 4),
#  ('Todder', 4),
#  ('Tysha', 4),
#  ('Unella', 4),
#  ('Weasel', 4),
#  ('Willem-Lannister', 4),
#  ('Wun-Weg-Wun-Dar-Wun', 4),
#  ('Wyl-(guard)', 4),
#  ('Zollo', 4),
#  ('Alysane-Mormont', 3),
#  ('Beth-Cassel', 3),
#  ('Brea', 3),
#  ('Balman-Byrch', 3),
#  ('Baelor-I-Targaryen', 3),
#  ('Chiggen', 3),
#  ('Clayton-Suggs', 3),
#  ('Cley-Cerwyn', 3),
#  ('Conn', 3),
#  ('Creighton-Longbough', 3),
#  ('Dacey-Mormont', 3),
#  ('Cleon', 3),
#  ('Daven-Lannister', 3),
#  ('Allard-Seaworth', 3),
#  ('Andrew-Estermont', 3),
#  ('Dunstan-Drumm', 3),
#  ('Dalbridge', 3),
#  ('Cayn', 3),
#  ('Elder-Brother', 3),
#  ('Emmon-Cuy', 3),
#  ('Arron', 3),
#  ('Emrick', 3),
#  ('Eon-Hunter', 3),
#  ('Franklyn-Flowers', 3),
#  ('Ballabar', 3),
#  ('Cutjack', 3),
#  ('Genna-Lannister', 3),
#  ('Grazhar', 3),
#  ('Errok', 3),
#  ('Grigg', 3),
#  ('Grunt', 3),
#  ('Garth-Greyfeather', 3),
#  ('Hairy-Hal', 3),
#  ('Albett', 3),
#  ('Harren-Hoare', 3),
#  ('Harrold-Hardyng', 3),
#  ('Harry-Strickland', 3),
#  ('High-Septon-(fat_one)', 3),
#  ('Hop-Robin', 3),
#  ('Danwell-Frey', 3),
#  ('Amerei-Frey', 3),
#  ('Jared-Frey', 3),
#  ('Jason-Mallister', 3),
#  ('Gared', 3),
#  ('Jarman-Buckwell', 3),
#  ('Alys-Karstark', 3),
#  ('Kasporio', 3),
#  ('Khorane-Sathmantes', 3),
#  ('Lambert-Turnberry', 3),
#  ('Leobald-Tallhart', 3),
#  ('Brus-Buckler', 3),
#  ('Marwyn', 3),
#  ('Miklaz', 3),
#  ('Moelle', 3),
#  ('Monford-Velaryon', 3),
#  ('Myranda-Royce', 3),
#  ('Narbert', 3),
#  ('Ogo', 3),
#  ('Osfryd-Kettleblack', 3),
#  ('Oswell-Whent', 3),
#  ('Porridge', 3),
#  ('Qarl-the-Maid', 3),
#  ('Qavo-Nogarys', 3),
#  ('Raynald-Westerling', 3),
#  ('Red-Oarsman', 3),
#  ('Robar-Royce', 3),
#  ('Robin-Flint', 3),
#  ('Scolera', 3),
#  ('Chella', 3),
#  ('Squint', 3),
#  ('Steelskin', 3),
#  ('Stygg', 3),
#  ('Sweets', 3),
#  ('Symon-Silver-Tongue', 3),
#  ('Terrance-Lynderly', 3),
#  ('Toregg', 3),
#  ('Torrhen-Karstark', 3),
#  ('Tristifer-Botley', 3),
#  ('Tybero-Istarion', 3),
#  ('Tycho-Nestoris', 3),
#  ('Utherydes-Wayn', 3),
#  ('Vyman', 3),
#  ('Walder-Frey-(son-of-Jammos)', 3),
#  ('Waymar-Royce', 3),
#  ('Xaro-Xhoan-Daxos', 3),
#  ('Yellow-Dick', 3),
#  ('Amabel', 2),
#  ('Brusco', 2),
#  ('Brynden-Rivers', 2),
#  ('Cedra', 2),
#  ('Chayle', 2),
#  ('Colen-of-Greenpools', 2),
#  ('Clubfoot-Karl', 2),
#  ('Daeron-II-Targaryen', 2),
#  ('Denyo-Terys', 2),
#  ('Desmond', 2),
#  ('Dirk', 2),
#  ('Daemon-Sand', 2),
#  ('Bannen', 2),
#  ('Daryn-Hornwood', 2),
#  ('Eldon-Estermont', 2),
#  ('Alys-Arryn', 2),
#  ('Forley-Prester', 2),
#  ('Gariss', 2),
#  ('Garth-(Wolfs-Den)', 2),
#  ('Ghael', 2),
#  ('Gendel', 2),
#  ('Gorne', 2),
#  ('Gorold-Goodbrother', 2),
#  ('Cromm', 2),
#  ('Guncer-Sunglass', 2),
#  ('Guyard-Morrigen', 2),
#  ('Gynir', 2),
#  ('Harra', 2),
#  ('Hayhead', 2),
#  ('Frenya', 2),
#  ('Horas-Redwyne', 2),
#  ('Howland-Reed', 2),
#  ('Dick-Straw', 2),
#  ('Humfrey-Hewett', 2),
#  ('Husband', 2),
#  ('Illifer', 2),
#  ('Clement-Piper', 2),
#  ('Allar-Deem', 2),
#  ('Gawen-Westerling', 2),
#  ('Hallyne', 2),
#  ('Jommo', 2),
#  ('Big-Boil', 2),
#  ('Brandon-Norrey', 2),
#  ('Dick-Follard', 2),
#  ('Fulk', 2),
#  ('Gerrick-Kingsblood', 2),
#  ('Jon-Umber-(Smalljon)', 2),
#  ('Jonos-Bracken', 2),
#  ('Florian-the-Fool', 2),
#  ('Heward', 2),
#  ('Joseth', 2),
#  ('Josmyn-Peckledon', 2),
#  ('Kedry', 2),
#  ('Kindly-Man', 2),
#  ('Kojja-Mo', 2),
#  ('Koss', 2),
#  ('Kraznys-mo-Nakloz', 2),
#  ('Leaf', 2),
#  ('Leona-Woolfield', 2),
#  ('Jonothor-Darry', 2),
#  ('Lyonel-Corbray', 2),
#  ('Alerie-Hightower', 2),
#  ('Mag-Mar-Tun-Doh-Weg', 2),
#  ('Maggy', 2),
#  ('Joramun', 2),
#  ('Mariya-Darry', 2),
#  ('Marlon-Manderly', 2),
#  ('Marselen', 2),
#  ('Marya-Seaworth', 2),
#  ('Meldred-Merlyn', 2),
#  ('Mellei', 2),
#  ('Merrett-Frey', 2),
#  ('Mezzara', 2),
#  ('Morra', 2),
#  ('Jyck', 2),
#  ('Morrec', 2),
#  ('Murenmure', 2),
#  ('Myles-Toyne', 2),
#  ('Benethon-Scales', 2),
#  ('Nyessos-Vhassar', 2),
#  ('Anders-Yronwood', 2),
#  ('Butterbumps', 2),
#  ('Orell', 2),
#  ('Oznak-zo-Pahl', 2),
#  ('Oswell-Kettleblack', 2),
#  ('Prendahl-na-Ghezn', 2),
#  ('Preston-Greenfield', 2),
#  ('Pyat-Pree', 2),
#  ('Puckens', 2),
#  ('Quellon-Greyjoy', 2),
#  ('Ralf-Stonehouse', 2),
#  ('Ben-Bones', 2),
#  ('Palla', 2),
#  ('Raymun-Darry', 2),
#  ('Raynard', 2),
#  ('Lucas-Codd', 2),
#  ('Reek', 2),
#  ('Rennifer-Longwaters', 2),
#  ('Rhaegar-Frey', 2),
#  ('Rhaella-Targaryen', 2),
#  ('Rhaenys-Targaryen', 2),
#  ('Ricasso', 2),
#  ('Richard-Horpe', 2),
#  ('Rickard-Stark', 2),
#  ('Olyvar-Frey', 2),
#  ('Perwyn-Frey', 2),
#  ('Gyles-Grafton', 2),
#  ('Robin-Ryger', 2),
#  ('Rodrik-Sparr', 2),
#  ('Roger-Ryswell', 2),
#  ('Rollam-Westerling', 2),
#  ('Ronnet-Connington', 2),
#  ('Rory', 2),
#  ('Petyr-Frey', 2),
#  ('Sallor', 2),
#  ('Quhuru-Mo', 2),
#  ('Brella', 2),
#  ('Senelle', 2),
#  ('Shadrich', 2),
#  ('Sigfryd-Harlaw', 2),
#  ('Smiling-Knight', 2),
#  ('Drennan', 2),
#  ('Steffon-Baratheon', 2),
#  ('Stiv', 2),
#  ('Sybelle-Glover', 2),
#  ('Symon-Stripeback', 2),
#  ('Talea', 2),
#  ('Ternesio-Terys', 2),
#  ('Theomore', 2),
#  ('Torrhen-Stark', 2),
#  ('Trystane-Martell', 2),
#  ('Scar', 2),
#  ('Martyn-Lannister', 2),
#  ('Urzen', 2),
#  ('Visenya-Targaryen', 2),
#  ('Vylarr', 2),
#  ('Waif', 2),
#  ('Walda-Frey-(daughter-of-Merrett)', 2),
#  ('Walgrave', 2),
#  ('Werlag', 2),
#  ('Wick-Whittlestick', 2),
#  ('Will-(prologue)', 2),
#  ('Willam-Dustin', 2),
#  ('Willow-Heddle', 2),
#  ('Wylis-Manderly', 2),
#  ('Xhondo', 2),
#  ('Aegon-V-Targaryen', 1),
#  ('Arthor-Karstark', 1),
#  ('Bellegere-Otherys', 1),
#  ('Brenett', 1),
#  ('Clarence-Crabb', 1),
#  ('Coratt', 1),
#  ('Byam-Flint', 1),
#  ('Barsena', 1),
#  ('Dancy', 1),
#  ('Bartimus', 1),
#  ('Denys-Darklyn', 1),
#  ('Dobber', 1),
#  ('Donnel-Waynwood', 1),
#  ('Elbert-Arryn', 1),
#  ('Ashara-Dayne', 1),
#  ('Elys-Waynwood', 1),
#  ('Emmond', 1),
#  ('Eroeh', 1),
#  ('Eustace-Brune', 1),
#  ('Ezzara', 1),
#  ('Black-Balaq', 1),
#  ('Franklyn-Fowler', 1),
#  ('Frenken', 1),
#  ('Garth-Tyrell', 1),
#  ('Gelmarr', 1),
#  ('Gerald-Gower', 1),
#  ('Godric-Borrell', 1),
#  ('Gormond-Goodbrother', 1),
#  ('Greydon-Goodbrother', 1),
#  ('Hali', 1),
#  ('Hobber-Redwyne', 1),
#  ('Hugh-Hungerford', 1),
#  ('Imry-Florent', 1),
#  ('Jacks', 1),
#  ('Aemon-Targaryen-(Dragonknight)', 1),
#  ('Bonifer-Hasty', 1),
#  ('Garrett-Paege', 1),
#  ('Hoster-Blackwood', 1),
#  ('Hugo-Vance', 1),
#  ('Jafer-Flowers', 1),
#  ('Blane', 1),
#  ('Jeyne-Heddle', 1),
#  ('Hugh', 1),
#  ('Arson', 1),
#  ('Hake', 1),
#  ('Jonquil', 1),
#  ('Joss', 1),
#  ('Joy-Hill', 1),
#  ('Kurz', 1),
#  ('Lanna-(Happy-Port)', 1),
#  ('Larraq', 1),
#  ('Jack-Be-Lucky', 1),
#  ('Leonette-Fossoway', 1),
#  ('Lewys-Piper', 1),
#  ('Harl', 1),
#  ('Lucifer-Long', 1),
#  ('Lynesse-Hightower', 1),
#  ('Lysono-Maar', 1),
#  ('Mad-Huntsman', 1),
#  ('Jaehaerys-I-Targaryen', 1),
#  ('Maekar-I-Targaryen', 1),
#  ('Marghaz-zo-Loraq', 1),
#  ('Mark-Mullendore', 1),
#  ('Maron-Greyjoy', 1),
#  ('Masha-Heddle', 1),
#  ('Jon-Fossoway', 1),
#  ('Matthar', 1),
#  ('Matthos-Seaworth', 1),
#  ('Mebble', 1),
#  ('Jeyne-Farman', 1),
#  ('Meralyn', 1),
#  ('Denzo-Dhan', 1),
#  ('Grazdan-mo-Eraz', 1),
#  ('Merrit', 1),
#  ('Draqaz', 1),
#  ('Ardrian-Celtigar', 1),
#  ('Moreo-Tumitis', 1),
#  ('Murch', 1),
#  ('Mychel-Redfort', 1),
#  ('Malaquo-Maegyr', 1),
#  ('Fogo', 1),
#  ('Othor', 1),
#  ('Owen-Merryweather', 1),
#  ('Pate-(Old)', 1),
#  ('Grisel', 1),
#  ('Cedric-Payne', 1),
#  ('Porther', 1),
#  ('Poxy-Tym', 1),
#  ('Praed', 1),
#  ('Quaithe', 1),
#  ('Old-Bill-Bone', 1),
#  ('Quill', 1),
#  ('Ragwyle', 1),
#  ('Arwyn-Oakheart', 1),
#  ('Ravella-Swann', 1),
#  ('Raymun-Redbeard', 1),
#  ('Lorent-Caswell', 1),
#  ('Rhaegel-Targaryen', 1),
#  ('Rhaego', 1),
#  ('Rhaenys-Targaryen-(daughter-of-Rhaegar)', 1),
#  ('Manfrey-Martell', 1),
#  ('Martyn-Rivers', 1),
#  ('Aerys-I-Targaryen', 1),
#  ('Halys-Hornwood', 1),
#  ('Rolfe-the-Dwarf', 1),
#  ('Rolph-Spicer', 1),
#  ('Rosey', 1),
#  ('Rossart', 1),
#  ('Rugen', 1),
#  ('Rus', 1),
#  ('Aron-Santagar', 1),
#  ('Kella', 1),
#  ('Sawane-Botley', 1),
#  ('Selwyn-Tarth', 1),
#  ('Dolf', 1),
#  ('Daeron-I-Targaryen', 1),
#  ('Shitmouth', 1),
#  ('Shortear', 1),
#  ('Luton', 1),
#  ('Simon-Toyne', 1),
#  ('Softfoot', 1),
#  ('Soren-Shieldbreaker', 1),
#  ('Camarron', 1),
#  ('Azor-Ahai', 1),
#  ('Corliss-Penny', 1),
#  ('Lyanna-Mormont', 1),
#  ('Roose-Ryswell', 1),
#  ('Steffon-Varner', 1),
#  ('Tarber', 1),
#  ('Gerold-Grafton', 1),
#  ('Theobald', 1),
#  ('Captain-Myraham', 1),
#  ('Captain-Myraham-Daughter', 1),
#  ('Farlen', 1),
#  ('Harwood-Stout', 1),
#  ('Kyra', 1),
#  ('Mallador-Locke', 1),
#  ('Timoth', 1),
#  ('Tobho-Mott', 1),
#  ('Tom-Barleycorn', 1),
#  ('Pate-(whipping-boy)', 1),
#  ('Torbert', 1),
#  ('Torghen-Flint', 1),
#  ('Torgon-Greyiron', 1),
#  ('Dryn', 1),
#  ('Munda', 1),
#  ('Torwold-Browntooth', 1),
#  ('Tregar', 1),
#  ('Tristifer-IV-Mudd', 1),
#  ('Sarella-Sand', 1),
#  ('Chataya', 1),
#  ('Galyeon-of-Cuy', 1),
#  ('Gunthor-son-of-Gurn', 1),
#  ('Kurleket', 1),
#  ('Leo-Lefford', 1),
#  ('Mord', 1),
#  ('Morgo', 1),
#  ('Shrouded-Lord', 1),
#  ('Joanna-Lannister', 1),
#  ('Ulf-son-of-Umar', 1),
#  ('Ulmer', 1),
#  ('Umma', 1),
#  ('Urswyck', 1),
#  ('Bump', 1),
#  ('Haggon', 1),
#  ('Thistle', 1),
#  ('Varly', 1),
#  ('Harras-Harlaw', 1),
#  ('Kerwin', 1),
#  ('Longwater-Pyke', 1),
#  ('Ralf-(Limper)', 1),
#  ('Talbert-Serry', 1),
#  ('Gormon-Tyrell', 1),
#  ('Nage', 1),
#  ('Watt', 1),
#  ('Shadd', 1),
#  ('Widower', 1),
#  ('Tion-Frey', 1),
#  ('William-Foxglove', 1),
#  ('Willow-Witch-eye', 1),
#  ('Wulfe', 1),
#  ('Wylla', 1),
#  ('Wynton-Stout', 1),
#  ('Bael-the-Bard', 1),
#  ('Yorko-Terys', 1),
#  ('Yurkhaz-zo-Yunzak', 1),
#  ('Zei', 1)]

# %% [markdown]
# ### **Creating functions to calculate the number of unique connections per character, Degree Centrality, Eigenvector Centrality, and Betweenness Centrality**

# %%
# The number of unique connections

def numUniqueConnec(G):
    numUniqueConnection = list(G.degree())
    
    numUniqueConnection = sorted(numUniqueConnection, key = lambda x:x[1], reverse = True)
    
    numUniqueConnection = pd.DataFrame.from_dict(numUniqueConnection)
    
    numUniqueConnection.columns = (["Character", "NumUniqueHCPConnections"])
    
    return numUniqueConnection

# %%
numUniqueConnec(G)
# Out:
#              Character  NumUniqueHCPConnections
# 0     Tyrion-Lannister                      122
# 1             Jon-Snow                      114
# 2      Jaime-Lannister                      101
# 3     Cersei-Lannister                       97
# 4    Stannis-Baratheon                       89
# ..                 ...                      ...
# 791       Wynton-Stout                        1
# 792      Bael-the-Bard                        1
# 793        Yorko-Terys                        1
# 794  Yurkhaz-zo-Yunzak                        1
# 795                Zei                        1
#
# [796 rows x 2 columns]

# %%
# Degree Centrality

def deg_central(G):
    deg_centrality = nx.degree_centrality(G)
    
    deg_centrality_sort = sorted(deg_centrality.items(), key = lambda x:x[1], reverse = True)
    
    deg_centrality_sort = pd.DataFrame.from_dict(deg_centrality_sort)
    
    deg_centrality_sort.columns = (["Character", "Degree Centrality"])
    
    return deg_centrality_sort

# %%
deg_cen_sort = deg_central(G)
deg_cen_sort
# Out:
#              Character  Degree Centrality
# 0     Tyrion-Lannister               0.15
# 1             Jon-Snow               0.14
# 2      Jaime-Lannister               0.13
# 3     Cersei-Lannister               0.12
# 4    Stannis-Baratheon               0.11
# ..                 ...                ...
# 791       Wynton-Stout               0.00
# 792      Bael-the-Bard               0.00
# 793        Yorko-Terys               0.00
# 794  Yurkhaz-zo-Yunzak               0.00
# 795                Zei               0.00
#
# [796 rows x 2 columns]

# %%
#Eigenvector Centrality

def eigen_central(G):
    eigen_centrality = nx.eigenvector_centrality(G, weight = "weight")
    
    eigen_centrality_sort = sorted(eigen_centrality.items(), key = lambda x:x[1], reverse = True)
    
    eigen_centrality_sort = pd.DataFrame.from_dict(eigen_centrality_sort)
    
    eigen_centrality_sort.columns = (["Character", "EigenVector Centrality"])
    
    return eigen_centrality_sort

eigen_central(G)
# Out:
#               Character  EigenVector Centrality
# 0      Tyrion-Lannister                    0.38
# 1      Cersei-Lannister                    0.36
# 2     Joffrey-Baratheon                    0.34
# 3      Robert-Baratheon                    0.28
# 4          Eddard-Stark                    0.28
# ..                  ...                     ...
# 791         Simon-Toyne                    0.00
# 792     Hugh-Hungerford                    0.00
# 793               Murch                    0.00
# 794  Torwold-Browntooth                    0.00
# 795       Gormon-Tyrell                    0.00
#
# [796 rows x 2 columns]

# %%
#Betweenness Centrality

def betweenness_central(G):
    betweenness_centrality = nx.betweenness_centrality(G, weight = "weight")
    
    betweenness_centrality_sort = sorted(betweenness_centrality.items(), key = lambda x:x[1], reverse = True)
    
    betweenness_centrality_sort = pd.DataFrame.from_dict(betweenness_centrality_sort)
    
    betweenness_centrality_sort.columns = (["Character", "Betweenness Centrality"])
    
    return betweenness_centrality_sort

betweenness_central(G)
# Out:
#               Character  Betweenness Centrality
# 0              Jon-Snow                    0.13
# 1         Theon-Greyjoy                    0.12
# 2       Jaime-Lannister                    0.12
# 3    Daenerys-Targaryen                    0.09
# 4     Stannis-Baratheon                    0.09
# ..                  ...                     ...
# 791              Yandry                    0.00
# 792       Bael-the-Bard                    0.00
# 793         Yorko-Terys                    0.00
# 794   Yurkhaz-zo-Yunzak                    0.00
# 795                 Zei                    0.00
#
# [796 rows x 2 columns]

# %%
def draw_plotly_network_graph(Graph_obj, filter = None, filter_nodesbydegree = None):
    G_dup = Graph_obj.copy()

    degrees = nx.classes.degree(G_dup)
    
    degree_df = pd.DataFrame(degrees)
    
    if filter is not None:
        top = deg_centrality_sort[:filter_nodesbydegree]["Character"].values
        
        G_dup.remove_nodes_from([node
                             for node in G_dup.nodes
                             if node not in top
                            ]) # Filter out the nodes that fewer connections

    pos = nx.spring_layout(G_dup)

    for n, p in pos.items():
        G_dup.nodes[n]['pos'] = p

    edge_trace = go.Scatter(
        x = [],
        y = [],
        line = dict(width = 0.5, color = '#888'),
        hoverinfo = 'none',
        mode = 'lines')

    for edge in G_dup.edges():
        x0, y0 = G_dup.nodes[edge[0]]['pos']
        
        x1, y1 = G_dup.nodes[edge[1]]['pos']
        
        edge_trace['x'] += tuple([x0, x1, None])
        
        edge_trace['y'] += tuple([y0, y1, None])

    node_trace = go.Scatter(
        x = [],
        y = [],
        text = [],
        mode = 'markers',
        hoverinfo = 'text',
        marker = dict(
            showscale = True,
            colorscale = 'RdBu',
            reversescale = True,
            color = [],
            size = 15,
            colorbar = dict(
                thickness = 10,
                title = 'Node Connections',
                xanchor = 'left',
                titleside = 'right'
            ),
            line = dict(width = 0)))

    for node in G_dup.nodes():
        x, y = G_dup.nodes[node]['pos']
        
        node_trace['x'] += tuple([x])
        
        node_trace['y'] += tuple([y])

    for node, adjacencies in enumerate(G_dup.adjacency()):
        node_trace['marker']['color'] += tuple([int(degree_df[degree_df[0] == adjacencies[0]][1].values)])
        
        node_info = adjacencies[0] + '<br /># of connections: ' + str(int(degree_df[degree_df[0] == adjacencies[0]][1].values))
        
        node_trace['text'] += tuple([node_info])

    fig = go.Figure(data = [edge_trace, node_trace],
                 layout = go.Layout(
                    title = '<br>GOT network connections',
                    titlefont = dict(size = 20),
                    showlegend = False,
                    hovermode = 'closest',
                    margin = dict(b = 20, l = 5, r = 5, t = 0),
                    annotations=[ dict(
                        text = "",
                        showarrow = False,
                        xref = "paper", yref = "paper") ],
                    xaxis = dict(showgrid = False, zeroline = False, showticklabels = False),
                    yaxis = dict(showgrid = False, zeroline = False, showticklabels = False)))

    iplot(fig)

# %%
draw_plotly_network_graph(Graph_obj = G, filter = None, filter_nodesbydegree = None)

# Note: This cell will take sometime to run
# Out:
# <div>                            <div id="f0066292-351c-4c94-9785-5c3c7b77ec29" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f0066292-351c-4c94-9785-5c3c7b77ec29")) {                    Plotly.newPlot(                        "f0066292-351c-4c94-9785-5c3c7b77ec29",                        [{"hoverinfo":"none","line":{"color":"#888","width":0.5},"mode":"lines","x":[0.3398899435997009,0.17929288744926453,null,0.17929288744926453,0.3335629105567932,null,0.17929288744926453,0.13044115900993347,null,0.17929288744926453,0.18386372923851013,null,0.17929288744926453,0.2287440448999405,null,0.17929288744926453,0.17621281743049622,null,0.17929288744926453,0.16022510826587677,null,0.17929288744926453,0.28541299700737,null,0.17929288744926453,0.12076212465763092,null,0.17929288744926453,0.19776713848114014,null,0.17929288744926453,0.16261570155620575,null,0.17929288744926453,0.206869974732399,null,0.17929288744926453,0.14612451195716858,null,0.17929288744926453,0.17910343408584595,null,0.17929288744926453,0.21155573427677155,null,0.17929288744926453,0.1092604249715805,null,0.17929288744926453,0.1704799234867096,null,0.17929288744926453,0.12663695216178894,null,0.17929288744926453,0.39059382677078247,null,0.17929288744926453,0.142161563038826,null,0.17929288744926453,0.21675945818424225,null,0.17929288744926453,0.1733102798461914,null,0.17929288744926453,0.011690021492540836,null,0.17929288744926453,0.15362043678760529,null,0.17929288744926453,0.01593795418739319,null,0.17929288744926453,0.40626096725463867,null,0.3335629105567932,0.4202827513217926,null,0.3335629105567932,0.3690205514431,null,0.3335629105567932,0.312583863735199,null,0.3335629105567932,0.4343888461589813,null,0.3335629105567932,0.46358010172843933,null,0.3335629105567932,0.4408732056617737,null,0.3335629105567932,0.15362043678760529,null,0.13044115900993347,0.18386372923851013,null,0.13044115900993347,0.17910343408584595,null,0.13044115900993347,0.17732685804367065,null,0.13044115900993347,0.1092604249715805,null,0.13044115900993347,0.1704799234867096,null,0.13044115900993347,0.01198367215692997,null,0.13044115900993347,0.12663695216178894,null,0.13044115900993347,0.142161563038826,null,0.13044115900993347,0.1733102798461914,null,0.13044115900993347,0.1993880271911621,null,0.13044115900993347,0.2077888548374176,null,0.13044115900993347,0.15362043678760529,null,0.13044115900993347,0.01593795418739319,null,0.13044115900993347,0.040379829704761505,null,-0.2557496428489685,-0.18692293763160706,null,-0.2557496428489685,-0.22512374818325043,null,-0.2557496428489685,-0.056241411715745926,null,-0.2557496428489685,-0.24841167032718658,null,-0.2557496428489685,-0.2641465663909912,null,-0.18692293763160706,-0.1406780183315277,null,-0.18692293763160706,-0.11045164614915848,null,-0.18692293763160706,-0.04688927158713341,null,-0.18692293763160706,-0.3145531117916107,null,-0.18692293763160706,-0.09750478714704514,null,-0.18692293763160706,-0.05013517662882805,null,-0.18692293763160706,-0.42552903294563293,null,-0.18692293763160706,-0.22512374818325043,null,-0.18692293763160706,-0.16680699586868286,null,-0.18692293763160706,-0.4410325288772583,null,-0.18692293763160706,-0.4475266933441162,null,-0.18692293763160706,-0.056241411715745926,null,-0.18692293763160706,-0.20289744436740875,null,-0.18692293763160706,-0.038707297295331955,null,-0.18692293763160706,-0.042900118976831436,null,-0.18692293763160706,-0.3176150321960449,null,-0.18692293763160706,-0.24841167032718658,null,-0.18692293763160706,-0.41100168228149414,null,-0.18692293763160706,-0.2641465663909912,null,-0.1406780183315277,-0.11045164614915848,null,-0.1406780183315277,-0.04688927158713341,null,-0.1406780183315277,-0.16652242839336395,null,-0.1406780183315277,-0.09750478714704514,null,-0.14067 ...

# %% [markdown]
# ### **All Books Combined**

# %%
draw_plotly_network_graph(Graph_obj = G, filter = "Yes", filter_nodesbydegree = 50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/1g/jdtvk8h90x70dl4b6ycgxcdw0000gn/T/ipykernel_67661/217676753.py in <module>
# ----> 1 draw_plotly_network_graph(Graph_obj = G, filter = "Yes", filter_nodesbydegree = 50)
#
# /var/folders/1g/jdtvk8h90x70dl4b6ycgxcdw0000gn/T/ipykernel_67661/672203050.py in draw_plotly_network_graph(Graph_obj, filter, filter_nodesbydegree)
#       7
#       8     if filter is not None:
# ----> 9         top = deg_centrality_sort[:filter_nodesbydegree]["Character"].values
#      10
#      11         G_dup.remove_nodes_from([node
#
# NameError: name 'deg_centrality_sort' is not defined

# %% [markdown]
# #### **Summary - Book 1**
#
# 1. **Eddard Stark** is the most connected character, followed by **Robert Baratheon**.
# 2. Tyrion, Catelyn, and Jon are in the top 5 characters.
# 3. Rob, Sansa, and Bran are all well-connected too, but the first book mostly revolves around Ed Stark and Robert Baratheon.
# 4. Cersei Lannister, Joffrey Baratheon, Jamie Lannister, Arya Stark, Daenerys, and Drogo are the other well-connected characters in this book.
#
# The above findings make sense considering the plot of Book 1. Robert Baratheon, the king of the seven kingdoms, visits the House of Stark to offer Eddard Stark the position of Hand of the King, which Stark accepts. Eddard Stark's two daughters Arya and Sansa, also accompany him to the King's Landing, while his son Robb Stark looks after the House of Stark in Eddard's absence. The book eventually ends with the death of Robert Baratheon and the execution of Ed Stark by the new king Joffrey Baratheon. Robert and Eddard's importance in the story and their links to other characters in the book makes it logical that they are the two most connected characters in Book 1 of the series, with the **highest Degree Centrality measures** as seen in the table below. Tyrion Lannister, already the next most important character in Book 1, gains prominence in the coming books and becomes the most connected character in the book series overall.

# %%
deg_central(G1)[:20]
# Out:
#              Character  Degree Centrality
# 0         Eddard-Stark               0.35
# 1     Robert-Baratheon               0.27
# 2     Tyrion-Lannister               0.25
# 3        Catelyn-Stark               0.23
# 4             Jon-Snow               0.20
# 5           Robb-Stark               0.19
# 6          Sansa-Stark               0.19
# 7           Bran-Stark               0.17
# 8     Cersei-Lannister               0.16
# 9    Joffrey-Baratheon               0.16
# 10     Jaime-Lannister               0.16
# 11          Arya-Stark               0.15
# 12       Petyr-Baelish               0.14
# 13     Tywin-Lannister               0.12
# 14  Daenerys-Targaryen               0.11
# 15         Jory-Cassel               0.11
# 16               Drogo               0.10
# 17       Rodrik-Cassel               0.10
# 18     Renly-Baratheon               0.10
# 19               Luwin               0.10
